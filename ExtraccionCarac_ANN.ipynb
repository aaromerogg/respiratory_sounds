# %%
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from os import listdir
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Base de datos:
#
# Elements contained in the filenames:
#
# 1.Patient number (101,102,...,226)
#
# 2.Recording index
#
# 3.Chest location (Trachea (Tc), {Anterior (A), Posterior (P),,Lateral (L)}{left (l), right (r)})
#
# 4.Acquisition mode (sequential/single channel (sc),simultaneous/multichannel (mc))
#
# 5.Recording equipment (AKG C417L Microphone, 3M Littmann Classic II SE Stethoscope, 3M Litmmann 3200 Electronic Stethoscope, WelchAllyn Meditron Master Elite Electronic Stethoscope)
#
# The abbreviations used in the diagnosis file are:
# - COPD: Chronic Obstructive Pulmonary Disease
# - LRTI: Lower Respiratory Tract Infection
# - URTI: Upper Respiratory Tract Infection

# %%
directory= "/content/drive/My Drive/Respiratory_Sound_Database/audio_and_txt_files/"#depende de cada drive
def ls(ruta = '.'):
    return listdir(ruta)
archivos=ls(directory)#lista de todos los archivos en la carpeta
archivos=[archivos[i][0:-4] for i in range(len(archivos)) if '.txt' in archivos[i]] #solo los nombres

litt=0
litt2=0
akg=0
Welch=0
for i in archivos:
  if 'AKGC417L' in i:
    akg+=1
  if 'LittC2SE' in i:
    litt+=1
  if 'Litt3200' in i:
    litt2+=1
  if 'Meditron' in i:
    Welch+=1

print('Grabaciones con AKG C417L: ', akg,'\nGrabaciones con LittC2SE: ',litt,
      '\nGrabaciones con Litt3200: ',litt2,'\nGrabaciones con WelchAllyn:', Welch,
      '\nGrabaciones totales: ',akg+litt+litt2+Welch)
# Out:
# Grabaciones con AKG C417L:  646
# Grabaciones con LittC2SE:  87
# Grabaciones con Litt3200:  60
# Grabaciones con WelchAllyn: 127
# Grabaciones totales:  920

# %%
# En el archivo patient_diagnosis.csv se tiene el diagnostico de cada paciente
# Se pasa cada diagnostico a forma binaria 
diagnosis=pd.read_csv("/content/drive/My Drive/Respiratory_Sound_Database/patient_diagnosis.csv",header=None,names=['paciente','diagnostico'])
d=pd.get_dummies(diagnosis, columns = ['diagnostico'],sparse=False)
d
# Out:
#      paciente  diagnostico_Asthma  ...  diagnostico_Pneumonia  diagnostico_URTI
# 0         101                   0  ...                      0                 1
# 1         102                   0  ...                      0                 0
# 2         103                   1  ...                      0                 0
# 3         104                   0  ...                      0                 0
# 4         105                   0  ...                      0                 1
# ..        ...                 ...  ...                    ...               ...
# 121       222                   0  ...                      0                 0
# 122       223                   0  ...                      0                 0
# 123       224                   0  ...                      0                 0
# 124       225                   0  ...                      0                 0
# 125       226                   0  ...                      1                 0
#
# [126 rows x 9 columns]

# %%
#Caracterizacion base de datos:
columnas=d.keys()[1:]
for k in columnas:
  print('Pacientes con ', k,':',sum(d[k].values))
print('Total de pacientes: ', len(d['paciente'].values))
# Out:
# Pacientes con  diagnostico_Asthma : 1
# Pacientes con  diagnostico_Bronchiectasis : 7
# Pacientes con  diagnostico_Bronchiolitis : 6
# Pacientes con  diagnostico_COPD : 64
# Pacientes con  diagnostico_Healthy : 26
# Pacientes con  diagnostico_LRTI : 2
# Pacientes con  diagnostico_Pneumonia : 6
# Pacientes con  diagnostico_URTI : 14
# Total de pacientes:  126

# %%
#Para el caso de EPOC (COPD) se nesecita saber las fuentes de adquisicion
c1=c2=c3=c4=0
a=d[d['diagnostico_COPD']==1]['paciente'].values
for i in archivos:
  num_paciente=int(i[:3])
  for z in a:
    if num_paciente==z and ('AKGC417L' in i):
      c1+=1
      a=a[a!=num_paciente]
      break
    if num_paciente==z and ('LittC2SE' in i):
      c2+=1
      a=a[a!=num_paciente]
      break
    if num_paciente==z and ('Litt3200' in i):
      c3+=1
      a=a[a!=num_paciente]
      break
    if num_paciente==z and ('Meditron' in i):
      c4+=1
      a=a[a!=num_paciente]
      break
c1,c2,c3,c4
# Out:
# (32, 15, 9, 8)

# %% [markdown]
# # Extracción de Características
#
# Luego de hacer una exploracon inicial y entrenando varios modelos se opto por solo usar características basadas en las MFCC.
#
# Cada archivo de audio viene acopañado de anotaciones de inicio, fin de ciclo y presencia de crujidos y silibancias con el mismo nombre en fotmato .txt.
#
# $
#  \begin{pmatrix}
#   ti & tf &  & c & w\\
#   1 & 2 &  & 0 & 1\\
#   2.2 & 3 &  & 1 & 0\\
#   3.5 & 4 &  & 1 & 1\\
#   4.1 & 5 &  & 0 & 0\\
#  \end{pmatrix}$

# %%
from scipy.signal import resample
import librosa as lb
# !pip install python_speech_features
from python_speech_features.base import mfcc
# Out:
# Requirement already satisfied: python_speech_features in /usr/local/lib/python3.6/dist-packages (0.6)

# %%
def respiratory_cycle(s,resampl=0):
  '''
  Esta función extrae los ciclos respiratorios.
  Parametros
    s: nombre del archivo a leer (sin .wav)
    resampl: frecuencia a la que se quiere convertir
  Devuelve 
    data: conjunto de datos con los ciclos
    rate: frecuencia de muestreo de salida
    df_annot: conjunto de anotaciones
  '''
  path=directory + s +'.wav'
  x, rate = lb.load(path)

  path=directory + s +'.txt'
  df_annot = pd.read_csv(path,sep="\t")
  df_annot=df_annot.values

  if resampl!=0:
    x=resample(x,int(len(x)*(resampl/rate)),axis=0)
    rate=resampl

  data=[]

  #separar los ciclos
  for i in range(np.shape(df_annot)[0]):
    y=x[int(df_annot[i,0]*rate):int(df_annot[i,1]*rate)]
    y=y/np.max(np.abs(y))#normaliza

    data.append(y)
  return data,rate,df_annot

# %%
f=archivos[33]
data,rate,df_annot=respiratory_cycle(f,resampl=4000)

print('Archivo: ',f)
print(df_annot,'fs salida: ',rate)

fig,ax=plt.subplots(nrows=1,ncols=3,figsize=(35,7))
s=data[0]
t=np.linspace(0,np.shape(s)[0]/rate,np.shape(s)[0])
ax[0].plot(t,s)
ax[0].set_title('Señal ciclo respiratorio')
ax[0].set_xlabel('Tiempo (s)')

t=np.linspace(0,np.shape(s)[0]/rate,np.shape(s)[0])
ax[1].plot(t[0:int(rate*0.05)],s[0:int(rate*0.05)])
ax[1].set_title('ventana de 50ms')
ax[1].set_xlabel('Tiempo (s)')

S=lb.feature.melspectrogram(y=s, sr=4000,n_fft=int(4000*0.05))
S_dB = lb.power_to_db(S, ref=np.max)
# img = lb.display.specshow(S_dB, x_axis='time',
#                          y_axis='mel', sr=4000,
#                          fmax=8000, ax=ax[2])
# fig.colorbar(img, ax=ax[2], format='%+2.0f dB')

ax[2].set(title='Mel-frequency spectrogram')
ax[2].imshow(S_dB)
# Out:
# Archivo:  200_2p4_Pr_mc_AKGC417L
# [[ 3.297  7.805  0.     0.   ]
#  [ 7.805 11.594  0.     0.   ]
#  [11.594 15.902  0.     0.   ]
#  [15.902 17.387  0.     0.   ]] fs salida:  4000

# %%
m=mfcc(s, samplerate=4000, winlen=0.05, winstep=0.05, numcep=12, nfft=int(4000*0.05))
plt.imshow(m)

# %%
def cycle_characteristics(s,rate,window):
  m=mfcc(s, samplerate=rate, winlen=window, winstep=window, numcep=12, nfft=int(rate*window))
  m=np.concatenate((np.mean(m,axis=0),np.std(m,axis=0)))
  return [m]

# %%
m=mfcc(s, samplerate=4000, winlen=0.05, winstep=0.05, numcep=12, nfft=int(4000*0.05))
m.shape
# Out:
# (91, 12)

# %%
cycle_characteristics(s,4000,0.05)
# Out:
# [array([-4.13577743, 10.00432957,  9.09846304,  4.14747002,  5.41550417,
#          3.22183514,  2.737689  ,  3.94930891,  2.21895203,  3.17607887,
#          3.40799526,  2.1421276 ,  0.70930811,  4.29925117,  4.95057235,
#          6.03305831,  5.62352456,  6.41274569,  6.13705098,  7.36207981,
#          6.01729058,  6.44801274,  7.04573671,  6.12946745])]

# %%
len(archivos)
# Out:
# 920

# %%
w=0.05#ventana en segundos

c = []
cont=0
targets = []
for archivo in archivos:#recorrer la lista de archivos
  
  data,rate,df_annot=respiratory_cycle(archivo,resampl=4000)
  label2=d.loc[d['paciente']==int(archivo[:3])].values[0,4]

  for k in range(np.shape(df_annot)[0]):
    if (df_annot[k,1] - df_annot[k,0]) > 0.2 :
      c.append(cycle_characteristics(data[k],rate,w))
      targets.append([df_annot[k,2],df_annot[k,3],label2])
  cont+=1
  print(cont)

# %%
carac=np.array(c,dtype=np.float64)
targets=np.array(targets,dtype=np.float64)

# %%
texto='''mfcc1 m, mfcc2 m, mfcc3 m, mfcc4 m, mfcc5 m, mfcc6 m, mfcc7 m, mfcc8 m, mfcc9 m, mfcc10 m, mfcc11 m, mfcc12 m,mfcc1 s, mfcc2 s, mfcc3 s, mfcc4 s, mfcc5 s, mfcc6 s, mfcc7 s, mfcc8 s, mfcc9 s, mfcc10 s, mfcc11 s, mfcc12 s,crackles,wheezes,diagnostic'''
datos=pd.DataFrame(np.concatenate((carac[:,0,:],targets),axis=1),columns=texto.split(','))
datos.to_csv('/content/drive/MyDrive/Proyecto DBIO/Caracteristicas/Caracteristicas_MFCC_50ms.csv')

# %% [markdown]
# #Exploracion de las características

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow.keras as kr
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import sys

# %%
def plot_model(model_details):

    # Create sub-plots
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    
    # Summarize history for accuracy
    axs[0].plot(range(1,len(model_details.history['binary_accuracy'])+1),model_details.history['binary_accuracy'])
    axs[0].plot(range(1,len(model_details.history['val_binary_accuracy'])+1),model_details.history['val_binary_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    #axs[0].set_xticks(np.arange(1,len(model_details.history['binary_accuracy'])+1),len(model_details.history['binary_accuracy'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    
    # Summarize history for loss
    axs[1].plot(range(1,len(model_details.history['loss'])+1),model_details.history['loss'])
    axs[1].plot(range(1,len(model_details.history['val_loss'])+1),model_details.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    #axs[1].set_xticks(np.arange(1,len(model_details.history['loss'])+1),len(model_details.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    
    # Show the plot
    plt.show()

# %%
path='/content/drive/MyDrive/Proyecto DBIO/Caracteristicas'
f=pd.read_csv(path+'/Caracteristicas_MFCC_50ms.csv',index_col=0)
f
# Out:
#        mfcc1 m    mfcc2 m    mfcc3 m  ...  crackles  wheezes  diagnostic
# 0    -4.325562  11.845219  14.293463  ...       0.0      0.0         0.0
# 1    -4.572113  11.064278  14.450975  ...       0.0      0.0         0.0
# 2    -4.769439  12.341134  15.792789  ...       0.0      0.0         0.0
# 3    -3.406861  10.450745  14.576128  ...       0.0      0.0         0.0
# 4    -3.862665  11.746682  15.302933  ...       0.0      0.0         0.0
# ...        ...        ...        ...  ...       ...      ...         ...
# 5973 -1.991363  -5.482871   2.849390  ...       0.0      0.0         1.0
# 5974 -1.371821  -3.813627   2.028092  ...       0.0      0.0         1.0
# 5975 -2.724116  -1.892179   1.830296  ...       0.0      0.0         1.0
# 5976 -2.103645  -1.235302   1.450567  ...       0.0      0.0         1.0
# 5977 -2.248502  -1.560940   2.323047  ...       0.0      0.0         1.0
#
# [5978 rows x 27 columns]

# %%
print('Número de muestras con crujidos: ',sum(f['crackles']),'\nNúmero de muestras con silibancias: ',sum(f['wheezes']),
      '\nNúmero de muestras totales: ',len(f))
# Out:
# Número de muestras con crujidos:  2078.0
# Número de muestras con silibancias:  1224.0
# Número de muestras totales:  5978

# %%
np.random.seed(1)
data=f.values
X = data[:,:-3]
Y = data[:,-3:-1] #target para c y w
Y_copd= data[:,-1] #target para epoc
#scaler = StandardScaler()
scaler =MinMaxScaler((-1,1),True)#Nomaliza entre -1 y 1
X=scaler.fit_transform(X)

test_size= int(X.shape[0]*0.20) #20% para prueba
val_size = int(X.shape[0]*0.1) #10% para validacion

d = np.random.choice(np.arange(X.shape[0]) , size=X.shape[0], replace=False)
x_test = X[d[:test_size],:] 
x_val  = X[d[test_size:test_size+val_size],:]
x_train= X[d[test_size+val_size:],:] 

y_test = Y[d[:test_size]] 
y_val  = Y[d[test_size:test_size+val_size]]
y_train= Y[d[test_size+val_size:]] 

y_test_copd = Y_copd[d[:test_size]] 
y_val_copd  = Y_copd[d[test_size:test_size+val_size]]
y_train_copd= Y_copd[d[test_size+val_size:]] 

print('Dimensiones de prueba, validacion, entrenamiento: ',x_test.shape,x_val.shape,x_train.shape)
# Out:
# Dimensiones de prueba, validacion, entrenamiento:  (1195, 24) (597, 24) (4186, 24)

# %%
plt.figure(figsize=(7,7))
df=pd.DataFrame(X)
plt.imshow(df.cov())

# %% [markdown]
# # Clasificación ANN

# %%
global best_val_acc 
global best_val_loss 
global best_parameters
best_val_acc = 0
best_val_loss = sys.float_info.max 
best_parameters=['none' for i in range(5)]#guardare 5 paramtros
class MyCallback(kr.callbacks.Callback):
    def __init__(self,lr,tam_batch,neuronas,act,filename):
        self.lr=lr
        self.tam_batch=tam_batch
        self.neuronas=neuronas
        self.act=act
        self.filename=filename
    def on_epoch_end(self, epoch, logs=None):
        global best_val_acc 
        global best_val_loss
        global best_parameters
        val_acc = logs['val_binary_accuracy']
        val_loss = logs['val_loss']

        # if val_acc > best_val_acc:
        #     self.model.save(filename)
        #     print('lr: '+ str(self.lr),'batch: '+ str(self.tam_batch), 
        #           'num_neu: '+ str(self.neuronas),'activation: '+ str(self.act), 'epoch: '+ str(epoch))
        #     print('Improve from: % 2.5f to % 2.5f in acc' %(best_val_acc,val_acc))
        #     best_val_acc = val_acc 
        #     best_parameters=[str(self.neuronas),str(self.lr),str(self.act),str(self.tam_batch)]
        # elif val_acc == best_val_acc:
        if val_loss < best_val_loss:
            
            self.model.save(self.filename)
            print('lr: '+ str(self.lr),'batch: '+ str(self.tam_batch), 
                  'num_neu: '+ str(self.neuronas),'activation: '+ str(self.act), 'epoch: '+ str(epoch)) 
            print('Improve from: % 2.5f to % 2.5f in loss' %(best_val_loss,val_loss))  
            best_val_loss=val_loss 
            best_parameters=[str(self.neuronas),str(self.lr),str(self.act),str(self.tam_batch)]

# %%
def model_g(numn=100,act='relu'):
  model = kr.Sequential()
    #capa 1
  model.add(kr.layers.Dense(numn, input_dim=24, activation=act))

  model.add(kr.layers.Dense(1, activation='sigmoid'))
  
  return model

# %%
v_n=np.sort(np.array([np.random.randint(i,i+20) for i in range(40,200,20)]))#num neuronas
v_b=np.sort(np.array([np.random.randint(i,i+20) for i in range(20,140,20)]))#batch
v_l=[1.0e-3]#lr
v_a=['relu']#Activacion
auc=kr.metrics.AUC(name='AUC',multi_label=True)
v_n,v_b,v_l,v_a
# Out:
# (array([ 49,  64,  97, 117, 123, 144, 167, 183]),
#  array([ 23,  59,  60,  86, 104, 123]),
#  [0.001],
#  ['relu'])

# %%
resultados=[]
for neuronas in v_n:
  for lr in v_l:
    for activacion in v_a:
      for bache in v_b:     
          model=model_g(numn=int(neuronas),act=activacion)

          model.compile(loss="binary_crossentropy",
                        optimizer=kr.optimizers.Adam(lr=lr), 
                        metrics=['binary_accuracy',auc])

          details=model.fit(x_train, y_train_copd,
                    batch_size = int(bache),
                    epochs = 300,
                    validation_data=(x_val,y_val_copd),
                    callbacks=[MyCallback(lr=lr,tam_batch=bache,neuronas=neuronas,act=activacion,filename='Mejor_MFCC.h5')],
                    verbose=0)
          
          resultados.append([neuronas,lr,activacion,bache,min(details.history['val_loss'])])
          print('Fin de modelo: ',neuronas , lr , activacion, bache)
model=kr.models.load_model('Mejor_MFCC.h5')
model.save('/content/drive/MyDrive/Proyecto DBIO/Mejor_MFCC.h5')
# Out:
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 0
# Improve from:  .00000 to  0.36465 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 1
# Improve from:  0.36465 to  0.29258 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 2
# Improve from:  0.29258 to  0.25568 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 3
# Improve from:  0.25568 to  0.23711 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 4
# Improve from:  0.23711 to  0.22506 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 5
# Improve from:  0.22506 to  0.21589 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 6
# Improve from:  0.21589 to  0.20960 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 7
# Improve from:  0.20960 to  0.20137 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 8
# Improve from:  0.20137 to  0.19714 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 10
# Improve from:  0.19714 to  0.18617 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 12
# Improve from:  0.18617 to  0.17660 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 13
# Improve from:  0.17660 to  0.17368 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 14
# Improve from:  0.17368 to  0.17190 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 15
# Improve from:  0.17190 to  0.17127 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 16
# Improve from:  0.17127 to  0.16525 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 17
# Improve from:  0.16525 to  0.16369 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 18
# Improve from:  0.16369 to  0.15925 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 19
# Improve from:  0.15925 to  0.15646 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 21
# Improve from:  0.15646 to  0.15039 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 23
# Improve from:  0.15039 to  0.14889 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 24
# Improve from:  0.14889 to  0.14812 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 25
# Improve from:  0.14812 to  0.14547 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 26
# Improve from:  0.14547 to  0.14129 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 28
# Improve from:  0.14129 to  0.14030 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 30
# Improve from:  0.14030 to  0.13472 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 31
# Improve from:  0.13472 to  0.13324 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 33
# Improve from:  0.13324 to  0.13186 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 35
# Improve from:  0.13186 to  0.13149 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 36
# Improve from:  0.13149 to  0.12888 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 37
# Improve from:  0.12888 to  0.12779 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 38
# Improve from:  0.12779 to  0.12422 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 42
# Improve from:  0.12422 to  0.12412 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 43
# Improve from:  0.12412 to  0.12277 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 44
# Improve from:  0.12277 to  0.12022 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 49
# Improve from:  0.12022 to  0.11941 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 52
# Improve from:  0.11941 to  0.11660 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 53
# Improve from:  0.11660 to  0.11511 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 58
# Improve from:  0.11511 to  0.11434 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 61
# Improve from:  0.11434 to  0.11286 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 63
# Improve from:  0.11286 to  0.11254 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 65
# Improve from:  0.11254 to  0.11200 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 68
# Improve from:  0.11200 to  0.11053 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 70
# Improve from:  0.11053 to  0.10888 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 73
# Improve from:  0.10888 to  0.10866 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 78
# Improve from:  0.10866 to  0.10790 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 82
# Improve from:  0.10790 to  0.10718 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 83
# Improve from:  0.10718 to  0.10599 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 84
# Improve from:  0.10599 to  0.10514 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 90
# Improve from:  0.10514 to  0.10422 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 101
# Improve from:  0.10422 to  0.10341 in loss
# lr: 0.001 batch: 23 num_neu: 49 activation: relu epoch: 140
# Improve from:  0.10341 to  0.10073 in loss
# Fin de modelo:  49 0.001 relu 23
# Fin de modelo:  49 0.001 relu 59
# lr: 0.001 batch: 60 num_neu: 49 activation: relu epoch: 146
# Improve from:  0.10073 to  0.10040 in loss
# lr: 0.001 batch: 60 num_neu: 49 activation: relu epoch: 150
# Improve from:  0.10040 to  0.09965 in loss
# lr: 0.001 batch: 60 num_neu: 49 activation: relu epoch: 152
# Improve from:  0.09965 to  0.09939 in loss
# lr: 0.001 batch: 60 num_neu: 49 activation: relu epoch: 158
# Improve from:  0.09939 to  0.09895 in loss
# lr: 0.001 batch: 60 num_neu: 49 activation: relu epoch: 162
# Improve from:  0.09895 to  0.09864 in loss
# lr: 0.001 batch: 60 num_neu: 49 activation: relu epoch: 174
# Improve from:  0.09864 to  0.09847 in loss
# lr: 0.001 batch: 60 num_neu: 49 activation: relu epoch: 187
# Improve from:  0.09847 to  0.09724 in loss
# lr: 0.001 batch: 60 num_neu: 49 activation: relu epoch: 269
# Improve from:  0.09724 to  0.09700 in loss
# lr: 0.001 batch: 60 num_neu: 49 activation: relu epoch: 278
# Improve from:  0.09700 to  0.09680 in loss
# lr: 0.001 batch: 60 num_neu: 49 activation: relu epoch: 290
# Improve from:  0.09680 to  0.09655 in loss
# Fin de modelo:  49 0.001 relu 60
# Fin de modelo:  49 0.001 relu 86
# lr: 0.001 batch: 104 num_neu: 49 activation: relu epoch: 192
# Improve from:  0.09655 to  0.09615 in loss
# lr: 0.001 batch: 104 num_neu: 49 activation: relu epoch: 193
# Improve from:  0.09615 to  0.09560 in loss
# lr: 0.001 batch: 104 num_neu: 49 activation: relu epoch: 194
# Improve from:  0.09560 to  0.09397 in loss
# lr: 0.001 batch: 104 num_neu: 49 activation: relu epoch: 197
# Improve from:  0.09397 to  0.09390 in loss
# lr: 0.001 batch: 104 num_neu: 49 activation: relu epoch: 203
# Improve from:  0.09390 to  0.09352 in loss
# lr: 0.001 batch: 104 num_neu: 49 activation: relu epoch: 206
# Improve from:  0.09352 to  0.09319 in loss
# lr: 0.001 batch: 104 num_neu: 49 activation: relu epoch: 207
# Improve from:  0.09319 to  0.09203 in loss
# lr: 0.001 batch: 104 num_neu: 49 activation: relu epoch: 216
# Improve from:  0.09203 to  0.09165 in loss
# lr: 0.001 batch: 104 num_neu: 49 activation: relu epoch: 217
# Improve from:  0.09165 to  0.09108 in loss
# lr: 0.001 batch: 104 num_neu: 49 activation: relu epoch: 222
# Improve from:  0.09108 to  0.09097 in loss
# lr: 0.001 batch: 104 num_neu: 49 activation: relu epoch: 228
# Improve from:  0.09097 to  0.09049 in loss
# lr: 0.001 batch: 104 num_neu: 49 activation: relu epoch: 233
# Improve from:  0.09049 to  0.08965 in loss
# lr: 0.001 batch: 104 num_neu: 49 activation: relu epoch: 234
# Improve from:  0.08965 to  0.08878 in loss
# lr: 0.001 batch: 104 num_neu: 49 activation: relu epoch: 259
# Improve from:  0.08878 to  0.08802 in loss
# lr: 0.001 batch: 104 num_neu: 49 activation: relu epoch: 275
# Improve from:  0.08802 to  0.08760 in loss
# lr: 0.001 batch: 104 num_neu: 49 activation: relu epoch: 280
# Improve from:  0.08760 to  0.08728 in loss
# Fin de modelo:  49 0.001 relu 104
# Fin de modelo:  49 0.001 relu 123
# Fin de modelo:  64 0.001 relu 23
# Fin de modelo:  64 0.001 relu 59
# Fin de modelo:  64 0.001 relu 60
# Fin de modelo:  64 0.001 relu 86
# Fin de modelo:  64 0.001 relu 104
# Fin de modelo:  64 0.001 relu 123
# Fin de modelo:  97 0.001 relu 23
# lr: 0.001 batch: 59 num_neu: 97 activation: relu epoch: 130
# Improve from:  0.08728 to  0.08706 in loss
# lr: 0.001 batch: 59 num_neu: 97 activation: relu epoch: 135
# Improve from:  0.08706 to  0.08649 in loss
# lr: 0.001 batch: 59 num_neu: 97 activation: relu epoch: 145
# Improve from:  0.08649 to  0.08465 in loss
# lr: 0.001 batch: 59 num_neu: 97 activation: relu epoch: 154
# Improve from:  0.08465 to  0.08457 in loss
# lr: 0.001 batch: 59 num_neu: 97 activation: relu epoch: 161
# Improve from:  0.08457 to  0.08447 in loss
# lr: 0.001 batch: 59 num_neu: 97 activation: relu epoch: 170
# Improve from:  0.08447 to  0.08436 in loss
# lr: 0.001 batch: 59 num_neu: 97 activation: relu epoch: 174
# Improve from:  0.08436 to  0.08417 in loss
# lr: 0.001 batch: 59 num_neu: 97 activation: relu epoch: 183
# Improve from:  0.08417 to  0.08417 in loss
# lr: 0.001 batch: 59 num_neu: 97 activation: relu epoch: 188
# Improve from:  0.08417 to  0.08383 in loss
# lr: 0.001 batch: 59 num_neu: 97 activation: relu epoch: 203
# Improve from:  0.08383 to  0.08229 in loss
# Fin de modelo:  97 0.001 relu 59
# Fin de modelo:  97 0.001 relu 60
# lr: 0.001 batch: 86 num_neu: 97 activation: relu epoch: 202
# Improve from:  0.08229 to  0.08178 in loss
# lr: 0.001 batch: 86 num_neu: 97 activation: relu epoch: 204
# Improve from:  0.08178 to  0.08177 in loss
# lr: 0.001 batch: 86 num_neu: 97 activation: relu epoch: 205
# Improve from:  0.08177 to  0.08150 in loss
# lr: 0.001 batch: 86 num_neu: 97 activation: relu epoch: 207
# Improve from:  0.08150 to  0.08148 in loss
# lr: 0.001 batch: 86 num_neu: 97 activation: relu epoch: 209
# Improve from:  0.08148 to  0.08074 in loss
# lr: 0.001 batch: 86 num_neu: 97 activation: relu epoch: 213
# Improve from:  0.08074 to  0.08046 in loss
# lr: 0.001 batch: 86 num_neu: 97 activation: relu epoch: 220
# Improve from:  0.08046 to  0.08023 in loss
# lr: 0.001 batch: 86 num_neu: 97 activation: relu epoch: 229
# Improve from:  0.08023 to  0.08023 in loss
# lr: 0.001 batch: 86 num_neu: 97 activation: relu epoch: 237
# Improve from:  0.08023 to  0.07971 in loss
# lr: 0.001 batch: 86 num_neu: 97 activation: relu epoch: 243
# Improve from:  0.07971 to  0.07793 in loss
# lr: 0.001 batch: 86 num_neu: 97 activation: relu epoch: 269
# Improve from:  0.07793 to  0.07770 in loss
# lr: 0.001 batch: 86 num_neu: 97 activation: relu epoch: 272
# Improve from:  0.07770 to  0.07689 in loss
# lr: 0.001 batch: 86 num_neu: 97 activation: relu epoch: 278
# Improve from:  0.07689 to  0.07687 in loss
# lr: 0.001 batch: 86 num_neu: 97 activation: relu epoch: 291
# Improve from:  0.07687 to  0.07680 in loss
# lr: 0.001 batch: 86 num_neu: 97 activation: relu epoch: 294
# Improve from:  0.07680 to  0.07660 in loss
# lr: 0.001 batch: 86 num_neu: 97 activation: relu epoch: 295
# Improve from:  0.07660 to  0.07533 in loss
# Fin de modelo:  97 0.001 relu 86
# Fin de modelo:  97 0.001 relu 104
# Fin de modelo:  97 0.001 relu 123
# Fin de modelo:  117 0.001 relu 23
# Fin de modelo:  117 0.001 relu 59
# Fin de modelo:  117 0.001 relu 60
# Fin de modelo:  117 0.001 relu 86
# Fin de modelo:  117 0.001 relu 104
# Fin de modelo:  117 0.001 relu 123
# Fin de modelo:  123 0.001 relu 23
# Fin de modelo:  123 0.001 relu 59
# Fin de modelo:  123 0.001 relu 60
# Fin de modelo:  123 0.001 relu 86
# Fin de modelo:  123 0.001 relu 104
# Fin de modelo:  123 0.001 relu 123
# Fin de modelo:  144 0.001 relu 23
# Fin de modelo:  144 0.001 relu 59
# Fin de modelo:  144 0.001 relu 60
# Fin de modelo:  144 0.001 relu 86
# Fin de modelo:  144 0.001 relu 104
# Fin de modelo:  144 0.001 relu 123
# Fin de modelo:  167 0.001 relu 23
# Fin de modelo:  167 0.001 relu 59
# Fin de modelo:  167 0.001 relu 60
# Fin de modelo:  167 0.001 relu 86
# Fin de modelo:  167 0.001 relu 104
# Fin de modelo:  167 0.001 relu 123
# Fin de modelo:  183 0.001 relu 23
# Fin de modelo:  183 0.001 relu 59
# Fin de modelo:  183 0.001 relu 60
# Fin de modelo:  183 0.001 relu 86
# Fin de modelo:  183 0.001 relu 104
# Fin de modelo:  183 0.001 relu 123

# %%
resultados=np.array(resultados)
datos=pd.DataFrame(resultados,columns=['num_neuronas','lr','fun_activacion','tam_bache','mejor_perdida'])

# %%
#queda guardado en la carpeta
datos.to_csv('/content/drive/MyDrive/Proyecto DBIO/busqueda_param_ruidos.csv')

# %% [markdown]
# Usar el archvo guardado

# %%
f=pd.read_csv('/content/drive/MyDrive/Proyecto DBIO/busqueda_param_ruidos.csv',index_col=0)
resultados=f.values

# %%
X_std = (resultados[:,4] - min(resultados[:,4])) / (max(resultados[:,4]) - min(resultados[:,4]))
resultados[:,4] = X_std

# %%
fig,axs=plt.subplots(nrows=1,ncols=1,figsize=(10,10))
axs.imshow(np.reshape(np.array(resultados[:,4],dtype=np.float32),(len(v_n),len(v_b))))
axs.set_xticks(np.arange(len(v_b)))
axs.set_xticklabels(v_b)
axs.set_xlabel('Tamaño del bache')
axs.set_yticks(np.arange(len(v_n)))
axs.set_yticklabels(v_n)
axs.set_ylabel('Número neuronas')
axs.set_title('Mapa de Calor\n act: relu   lr: 0.001')
# Out:
# Text(0.5, 1.0, 'Mapa de Calor\n act: relu   lr: 0.001')

# %% [markdown]
# mas exploración

# %% [markdown]
# #Modelo Final

# %%
model=kr.models.load_model('/content/drive/MyDrive/Proyecto DBIO/Mejor_MFCC.h5')
model.evaluate(x_train,y_train_copd)
model.evaluate(x_val,y_val_copd)
model.evaluate(x_test,y_test_copd)
model.summary()
# Out:
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0154 - binary_accuracy: 0.9974 - AUC: 1.0000
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0753 - binary_accuracy: 0.9698 - AUC: 0.9942
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0647 - binary_accuracy: 0.9766 - AUC: 0.9917
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 97)                2425
# _________________________________________________________________
# dense_31 (Dense)             (None, 1)                 98
# =================================================================
# Total params: 2,523
# Trainable params: 2,523
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
#---------------------------------------------------------------conjunto validacion
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(10,5))
y_pred_total=model.predict(x_val)
y_pred=y_pred_total[:,:]>0.8

cm = confusion_matrix(y_val_copd,y_pred,normalize='true')
cmp = ConfusionMatrixDisplay(cm, display_labels=('no EPOC','EPOC'))
ax[0].set_title('Validación')
cmp.plot(cmap='Blues',xticks_rotation='vertical',ax=ax[0])

y_pred_total=model.predict(x_test)
y_pred=y_pred_total[:,:]>0.8

cm = confusion_matrix(y_test_copd,y_pred,normalize='true')
cmp = ConfusionMatrixDisplay(cm, display_labels=('no EPOC','EPOC'))
ax[1].set_title('Prueba')
cmp.plot(cmap='Blues',xticks_rotation='vertical',ax=ax[1])

# %%
def model_g(numn=100,act='relu'):
  model = kr.Sequential()
    #capa 1
  model.add(kr.layers.Dense(numn, input_dim=24, activation=act))

  model.add(kr.layers.Dense(1, activation='sigmoid'))
  
  return model

model=model_g(numn=97,act='relu')

model.compile(loss="binary_crossentropy",
              optimizer=kr.optimizers.Adam(lr=0.001), 
              metrics=['binary_accuracy',auc])

details=model.fit(x_train, y_train_copd,
          batch_size = 86,
          epochs = 300,
          validation_data=(x_val,y_val_copd),
          verbose=0)

# %%
plot_model(details)
model.evaluate(x_train,y_train_copd)
model.evaluate(x_val,y_val_copd)
model.evaluate(x_test,y_test_copd)
model.summary()
# Out:
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0147 - binary_accuracy: 0.9976 - AUC: 1.0000
# 19/19 [==============================] - 0s 4ms/step - loss: 0.1053 - binary_accuracy: 0.9631 - AUC: 0.9883
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0544 - binary_accuracy: 0.9791 - AUC: 0.9970
# Model: "sequential_50"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_100 (Dense)            (None, 97)                2425
# _________________________________________________________________
# dense_101 (Dense)            (None, 1)                 98
# =================================================================
# Total params: 2,523
# Trainable params: 2,523
# Non-trainable params: 0
# _________________________________________________________________
